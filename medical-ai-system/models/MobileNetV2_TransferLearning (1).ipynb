# %% [markdown]
# # MobileNetV2 + Transfer Learning + Dense + Softmax
# ## Klasifikasi Citra Medis Ultrasound Payudara (BUSI Dataset)
# **Kategori:** Benign, Malignant, Normal
#
# ---
# **Cara Pakai:**
# 1. Jalankan cell 1: download dataset dari Kaggle (via kagglehub)
# 2. Cell 2: restruktur dataset ke folder per kelas
# 3. Jalankan cell-cell berikutnya berurutan
# 4. Cell terakhir: download hasil training ke komputer

# %% [markdown]
# ## 1. Download Dataset dari Kaggle

# %%
# Install kagglehub (tanpa perlu upload API key)
# !pip install -q kagglehub

import kagglehub
import os

print('Mendownload dataset BUSI dari Kaggle...')
path = kagglehub.dataset_download("aryashah2k/breast-ultrasound-images-dataset")
print(f'Dataset downloaded to: {path}')

# Copy ke folder Colab
# !cp -r "$path" /content/BUSI_Dataset
print('Dataset siap di /content/BUSI_Dataset')
# Out:
# Mendownload dataset BUSI dari Kaggle...
# Downloading to /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/1.archive...
# 100%|██████████| 195M/195M [00:00<00:00, 208MB/s]
# Extracting files...
# Dataset downloaded to: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1
# Dataset siap di /content/BUSI_Dataset

# %% [markdown]
# ## 2. Restruktur Dataset ke Folder per Kelas
#
# Dataset BUSI dari Kaggle menyimpan semua gambar di satu folder dengan nama file:
# - `benign (1).png`, `benign (2).png`, ...
# - `malignant (1).png`, `malignant (1).png`, ...
# - `normal (1).png`, `normal (2).png`, ...
#
# Cell ini akan memisahkan ke folder `benign/`, `malignant/`, `normal/`.

# %%
import shutil
import glob
import re

BASE_PATH = '/content/BUSI_Dataset'

# Cek struktur dataset
all_items = os.listdir(BASE_PATH)
print('Isi folder:', all_items[:20], '...' if len(all_items) > 20 else '')

# Jika sudah ada subfolder benign/malignant/normal, lewati
class_folders = ['benign', 'malignant', 'normal']
already_structured = any(os.path.isdir(os.path.join(BASE_PATH, d)) for d in class_folders if d in all_items)

if already_structured:
    print('Dataset sudah terstruktur dengan folder per kelas.')
else:
    print('Dataset flat. Memulai restruktur ke folder per kelas...')

    # Cari folder Dataset_BUSI_with_GT jika ada
    src_dir = BASE_PATH
    for item in all_items:
        item_path = os.path.join(BASE_PATH, item)
        if os.path.isdir(item_path) and 'BUSI' in item.upper():
            src_dir = item_path
            print(f'Folder dataset ditemukan: {item_path}')
            break

    # Buat folder per kelas
    target_dirs = {}
    for cls in class_folders:
        d = os.path.join(BASE_PATH, cls)
        os.makedirs(d, exist_ok=True)
        target_dirs[cls] = d

    # Ambil semua file gambar
    image_extensions = ('.png', '.jpg', '.jpeg', '.bmp', '.tiff')
    all_images = []
    for root, dirs, files in os.walk(src_dir):
        for f in files:
            if f.lower().endswith(image_extensions):
                all_images.append(os.path.join(root, f))

    print(f'Total gambar ditemukan: {len(all_images)}')

    # Pindahkan file berdasarkan prefix nama
    moved_count = 0
    mask_count = 0
    for img_path in all_images:
        fname = os.path.basename(img_path).lower()

        # Skip mask files
        if '_mask' in fname:
            mask_count += 1
            continue

        # Tentukan kelas dari prefix nama file
        if fname.startswith('benign'):
            target = target_dirs['benign']
        elif fname.startswith('malignant'):
            target = target_dirs['malignant']
        elif fname.startswith('normal'):
            target = target_dirs['normal']
        else:
            continue  # skip file tidak dikenal

        # Hindari duplikasi nama
        dest = os.path.join(target, fname)
        if os.path.exists(dest):
            base, ext = os.path.splitext(fname)
            dest = os.path.join(target, f'{base}_{moved_count}{ext}')

        shutil.move(img_path, dest)
        moved_count += 1

    print(f'Dipindahkan: {moved_count}')
    print(f'Mask files (diabaikan): {mask_count}')

    # Hapus folder kosong bekas
    if src_dir != BASE_PATH:
        shutil.rmtree(src_dir, ignore_errors=True)
        print(f'Folder {src_dir} dihapus.')

# Verifikasi akhir
print('\n=== Struktur final ===')
for cls in class_folders:
    cls_path = os.path.join(BASE_PATH, cls)
    if os.path.exists(cls_path):
        count = len([f for f in os.listdir(cls_path) if f.lower().endswith(image_extensions)])
        print(f'  {cls}/: {count} gambar')

print(f'\nDataset siap digunakan!')
# Out:
# Isi folder: ['Dataset_BUSI_with_GT']
# Dataset flat. Memulai restruktur ke folder per kelas...
# Folder dataset ditemukan: /content/BUSI_Dataset/Dataset_BUSI_with_GT
# Total gambar ditemukan: 1578
# Dipindahkan: 780
# Mask files (diabaikan): 798
# Folder /content/BUSI_Dataset/Dataset_BUSI_with_GT dihapus.
#
# === Struktur final ===
#   benign/: 437 gambar
#   malignant/: 210 gambar
#   normal/: 133 gambar
#
# Dataset siap digunakan!

# %% [markdown]
# ## 3. Import Library

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json
import os
import time
import datetime

print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %% [markdown]
# ## 4. Konfigurasi Parameter

# %%
BASE_PATH = '/content/BUSI_Dataset'
OUTPUT_DIR = '/content/BUSI_Model'
os.makedirs(OUTPUT_DIR, exist_ok=True)

IMG_HEIGHT, IMG_WIDTH = 224, 224
BATCH_SIZE = 32
EPOCHS_INITIAL = 20
EPOCHS_FINETUNE = 30
LEARNING_RATE_INITIAL = 1e-3
LEARNING_RATE_FINETUNE = 1e-5
VALIDATION_SPLIT = 0.2
TEST_SPLIT = 0.1
RANDOM_SEED = 42
N_CLASSES = 3
CLASS_NAMES = ['benign', 'malignant', 'normal']

print('Base path:', BASE_PATH)
print('Output dir:', OUTPUT_DIR)
print('Classes:', CLASS_NAMES)
# Out:
# Base path: /content/BUSI_Dataset
# Output dir: /content/BUSI_Model
# Classes: ['benign', 'malignant', 'normal']

# %% [markdown]
# ## 5. Data Augmentation & Preprocessing

# %%
# Augmentasi untuk training
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest',
    validation_split=VALIDATION_SPLIT + TEST_SPLIT
)

# Tanpa augmentasi untuk validation/test
val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=VALIDATION_SPLIT + TEST_SPLIT
)

# %% [markdown]
# ## 6. Load Dataset (Train / Val / Test)

# %%
# Training set
train_generator = train_datagen.flow_from_directory(
    BASE_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=RANDOM_SEED
)

# Validation + Test (gabung dulu)
val_test_generator = val_test_datagen.flow_from_directory(
    BASE_PATH,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    seed=RANDOM_SEED
)
# Out:
# Found 547 images belonging to 3 classes.
# Found 233 images belonging to 3 classes.

# %% [markdown]
# ## 7. Split Validation jadi Val + Test

# %%
# Kumpulkan semua file dari val_test_generator
all_filenames = val_test_generator.filenames
all_labels_orig = val_test_generator.labels
n_total = len(all_filenames)
n_test = int(n_total * TEST_SPLIT / (VALIDATION_SPLIT + TEST_SPLIT))

# Shuffle indices
np.random.seed(RANDOM_SEED)
indices = np.arange(n_total)
np.random.shuffle(indices)

test_indices = indices[:n_test]
val_indices = indices[n_test:]

print(f'Total val+test: {n_total}')
print(f'Test samples: {len(test_indices)}')
print(f'Validation samples: {len(val_indices)}')
print(f'Train samples: {train_generator.samples}')
# Out:
# Total val+test: 233
# Test samples: 77
# Validation samples: 156
# Train samples: 547

# %% [markdown]
# ## 8. Buat Generator Val & Test (via DataFrame)

# %%
def create_subset_generator(original_gen, indices):
    import pandas as pd
    # Ambil nama folder sebagai class label (string)
    class_labels = [all_filenames[i].split('/')[0] for i in indices]
    df = pd.DataFrame({
        'filename': [all_filenames[i] for i in indices],
        'class': class_labels
    })
    generator = val_test_datagen.flow_from_dataframe(
        df,
        directory=original_gen.directory,
        x_col='filename',
        y_col='class',
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False
    )
    return generator

val_generator = create_subset_generator(val_test_generator, val_indices)
test_generator = create_subset_generator(val_test_generator, test_indices)

print('Validation samples:', val_generator.samples)
print('Test samples:', test_generator.samples)
print('Class mapping:', train_generator.class_indices)
# Out:
# Found 156 validated image filenames belonging to 3 classes.
# Found 77 validated image filenames belonging to 3 classes.
# Validation samples: 156
# Test samples: 77
# Class mapping: {'benign': 0, 'malignant': 1, 'normal': 2}

# %% [markdown]
# ## 9. Bangun Arsitektur Model

# %%
# Load MobileNetV2 dengan pre-trained ImageNet weights
base_model = MobileNetV2(
    input_shape=(IMG_HEIGHT, IMG_WIDTH, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

# Freeze base model (transfer learning phase)
base_model.trainable = False

inputs = keras.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
x = preprocess_input(inputs)
x = base_model(x, training=False)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
outputs = Dense(N_CLASSES, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,619,203 (9.99 MB)
#  Trainable params: 361,219 (1.38 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ## 10. Compile Model (Phase 1 - Transfer Learning)

# %%
model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE_INITIAL),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## 11. Callbacks

# %%
best_model_path = os.path.join(OUTPUT_DIR, 'best_model_phase1.keras')
final_model_path = os.path.join(OUTPUT_DIR, 'model.keras')
tensorboard_log_dir = os.path.join(OUTPUT_DIR, 'logs', datetime.datetime.now().strftime('%Y%m%d-%H%M%S'))

callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=7,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        best_model_path,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    ),
    TensorBoard(
        log_dir=tensorboard_log_dir,
        histogram_freq=1
    )
]

print('Callbacks siap.')
# Out:
# Callbacks siap.

# %% [markdown]
# ## 12. Training Phase 1 (Feature Extraction)

# %%
start_time = time.time()

history_phase1 = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_data=val_generator,
    validation_steps=val_generator.samples // BATCH_SIZE + 1,
    epochs=EPOCHS_INITIAL,
    callbacks=callbacks,
    verbose=1
)

elapsed = time.time() - start_time
print(f'Phase 1 training selesai dalam {elapsed:.2f} detik')
# Out:
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4310 - loss: 1.3105
# Epoch 1: val_accuracy improved from None to 0.57051, saving model to /content/BUSI_Model/best_model_phase1.keras
#
# Epoch 1: finished saving model to /content/BUSI_Model/best_model_phase1.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 64s 3s/step - accuracy: 0.4660 - loss: 1.1983 - val_accuracy: 0.5705 - val_loss: 0.9635 - learning_rate: 0.0010
# Epoch 2/20
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4688 - loss: 1.0568
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - accuracy: 0.4688 - loss: 1.0568 - val_accuracy: 0.5705 - val_loss: 0.9602 - learning_rate: 0.0010
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.5417 - loss: 1.0263
# Epoch 3: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 14s 841ms/step - accuracy: 0.5282 - loss: 1.0248 - val_accuracy: 0.5705 - val_loss: 0.9586 - learning_rate: 0.0010
# Epoch 4/20
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4062 - loss: 1.0842
# Epoch 4: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 223ms/step - accuracy: 0.4062 - loss: 1.0842 - val_accuracy: 0.5705 - val_loss: 0.9602 - learning_rate: 0.0010
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.4916 - loss: 1.0500
# Epoch 5: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 855ms/step - accuracy: 0.5010 - loss: 1.0325 - val_accuracy: 0.5705 - val_loss: 0.9589 - learning_rate: 0.0010
# Epoch 6/20
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5625 - loss: 1.0005
# Epoch 6: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 236ms/step - accuracy: 0.5625 - loss: 1.0005 - val_accuracy: 0.5705 - val_loss: 0.9577 - learning_rate: 0.0010
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.5388 - loss: 1.0450
# Epoch 7: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 15s 897ms/step - accuracy: 0.5495 - loss: 1.0345 - val_accuracy: 0.5705 - val_loss: 0.9754 - learning_rate: 0.0010
# Epoch 8/20
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6250 - loss: 0.9400
# Epoch 8: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 231ms/step - accuracy: 0.6250 - loss: 0.9400 - val_accuracy: 0.5705 - val_loss: 0.9736 - learning_rate: 0.0010
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 617ms/step - accuracy: 0.5615 - loss: 1.0066
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 9: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 15s 877ms/step - accuracy: 0.5534 - loss: 1.0092 - val_accuracy: 0.5705 - val_loss: 0.9639 - learning_rate: 0.0010
# Epoch 10/20
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5938 - loss: 0.9892
# Epoch 10: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 243ms/step - accuracy: 0.5938 - loss: 0.9892 - val_accuracy: 0.5705 - val_loss: 0.9645 - learning_rate: 5.0000e-04
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.5415 - loss: 0.9852
# Epoch 11: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 14s 829ms/step - accuracy: 0.5495 - loss: 0.9985 - val_accuracy: 0.5705 - val_loss: 0.9623 - learning_rate: 5.0000e-04
# Epoch 12/20
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5312 - loss: 1.0220
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 12: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.5312 - loss: 1.0220 - val_accuracy: 0.5705 - val_loss: 0.9619 - learning_rate: 5.0000e-04
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.5688 - loss: 0.9646
# Epoch 13: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 14s 835ms/step - accuracy: 0.5456 - loss: 0.9931 - val_accuracy: 0.5705 - val_loss: 0.9627 - learning_rate: 2.5000e-04
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Phase 1 training selesai dalam 178.31 detik

# %% [markdown]
# ## 13. Fine Tuning (Phase 2)

# %%
# Unfreeze base model
base_model.trainable = True

# Freeze layer awal, fine tune layer akhir
fine_tune_at = 120
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

print(f'Fine tune from layer {fine_tune_at}')
print(f'Trainable layers: {len(base_model.layers) - fine_tune_at}')
# Out:
# Fine tune from layer 120
# Trainable layers: 35

# %%
# Re-compile dengan learning rate lebih rendah
model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE_FINETUNE),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
best_model_path_phase2 = os.path.join(OUTPUT_DIR, 'best_model_phase2.keras')

callbacks_phase2 = [
    EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=4,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        best_model_path_phase2,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    ),
    TensorBoard(
        log_dir=tensorboard_log_dir + '_finetune',
        histogram_freq=1
    )
]

# %%
start_time = time.time()

history_phase2 = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_data=val_generator,
    validation_steps=val_generator.samples // BATCH_SIZE + 1,
    epochs=EPOCHS_FINETUNE,
    callbacks=callbacks_phase2,
    verbose=1
)

elapsed = time.time() - start_time
print(f'Phase 2 training selesai dalam {elapsed:.2f} detik')
# Out:
# Epoch 1/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4660 - loss: 1.0538
# Epoch 1: val_accuracy improved from None to 0.57051, saving model to /content/BUSI_Model/best_model_phase2.keras
#
# Epoch 1: finished saving model to /content/BUSI_Model/best_model_phase2.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.4835 - loss: 1.0359 - val_accuracy: 0.5705 - val_loss: 0.9594 - learning_rate: 1.0000e-05
# Epoch 2/30
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.4688 - loss: 1.0167
# Epoch 2: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 228ms/step - accuracy: 0.4688 - loss: 1.0167 - val_accuracy: 0.5705 - val_loss: 0.9595 - learning_rate: 1.0000e-05
# Epoch 3/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.4568 - loss: 1.0843
# Epoch 3: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 14s 827ms/step - accuracy: 0.4913 - loss: 1.0398 - val_accuracy: 0.5705 - val_loss: 0.9608 - learning_rate: 1.0000e-05
# Epoch 4/30
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5312 - loss: 1.0335
# Epoch 4: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.5312 - loss: 1.0335 - val_accuracy: 0.5705 - val_loss: 0.9608 - learning_rate: 1.0000e-05
# Epoch 5/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 586ms/step - accuracy: 0.5254 - loss: 0.9848
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 5: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 824ms/step - accuracy: 0.5223 - loss: 0.9758 - val_accuracy: 0.5705 - val_loss: 0.9616 - learning_rate: 1.0000e-05
# Epoch 6/30
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3438 - loss: 1.1834
# Epoch 6: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.3438 - loss: 1.1834 - val_accuracy: 0.5705 - val_loss: 0.9616 - learning_rate: 5.0000e-06
# Epoch 7/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.5281 - loss: 0.9851
# Epoch 7: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 839ms/step - accuracy: 0.5437 - loss: 0.9830 - val_accuracy: 0.5705 - val_loss: 0.9631 - learning_rate: 5.0000e-06
# Epoch 8/30
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 1.0152
# Epoch 8: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - accuracy: 0.5000 - loss: 1.0152 - val_accuracy: 0.5705 - val_loss: 0.9631 - learning_rate: 5.0000e-06
# Epoch 9/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.5222 - loss: 0.9936
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 9: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 17s 831ms/step - accuracy: 0.5534 - loss: 0.9551 - val_accuracy: 0.5705 - val_loss: 0.9637 - learning_rate: 5.0000e-06
# Epoch 10/30
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4688 - loss: 1.0238
# Epoch 10: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 264ms/step - accuracy: 0.4688 - loss: 1.0238 - val_accuracy: 0.5705 - val_loss: 0.9636 - learning_rate: 2.5000e-06
# Epoch 11/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.5513 - loss: 0.9456
# Epoch 11: val_accuracy did not improve from 0.57051
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 16s 831ms/step - accuracy: 0.5476 - loss: 0.9609 - val_accuracy: 0.5705 - val_loss: 0.9642 - learning_rate: 2.5000e-06
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Phase 2 training selesai dalam 151.66 detik

# %% [markdown]
# ## 14. Evaluasi Model pada Data Test

# %%
if os.path.exists(best_model_path_phase2):
    model.load_weights(best_model_path_phase2)
    print('Loaded best weights from phase 2')

test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
print(f'Test Loss: {test_loss:.4f}')
# Out:
# Loaded best weights from phase 2
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - accuracy: 0.5455 - loss: 1.0125
# Test Accuracy: 54.55%
# Test Loss: 1.0125

# %%
test_generator.reset()
y_pred_prob = model.predict(test_generator, verbose=1)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = test_generator.classes[:len(y_pred)]

print('\n=== Classification Report ===')
print(classification_report(y_true, y_pred, target_names=list(test_generator.class_indices.keys()), zero_division=0))

acc = accuracy_score(y_true, y_pred)
print(f'Accuracy: {acc * 100:.2f}%')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#       benign       0.55      1.00      0.71        42
#    malignant       0.00      0.00      0.00        18
#       normal       0.00      0.00      0.00        17
#
#     accuracy                           0.55        77
#    macro avg       0.18      0.33      0.24        77
# weighted avg       0.30      0.55      0.39        77
#
# Accuracy: 54.55%

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=list(test_generator.class_indices.keys()),
            yticklabels=list(test_generator.class_indices.keys()))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Test Set')
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, 'confusion_matrix.png'), dpi=150)
plt.show()
print('Confusion matrix saved.')
# Out:
# Confusion matrix saved.

# %% [markdown]
# ## 15. Plot Training History

# %%
def combine_history(h1, h2):
    combined = {}
    for key in h1.history.keys():
        combined[key] = h1.history[key] + h2.history[key]
    return combined

full_history = combine_history(history_phase1, history_phase2)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(full_history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(full_history['val_accuracy'], label='Val Accuracy', linewidth=2)
plt.axvline(x=len(history_phase1.history['accuracy']), color='gray', linestyle='--', alpha=0.5, label='Fine Tune Start')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(alpha=0.3)

plt.subplot(1, 2, 2)
plt.plot(full_history['loss'], label='Train Loss', linewidth=2)
plt.plot(full_history['val_loss'], label='Val Loss', linewidth=2)
plt.axvline(x=len(history_phase1.history['loss']), color='gray', linestyle='--', alpha=0.5, label='Fine Tune Start')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, 'training_history.png'), dpi=150)
plt.show()
print('Training history plot saved.')
# Out:
# Training history plot saved.

# %% [markdown]
# ## 16. Simpan Model & Artifacts

# %%
# Simpan model
model.save(final_model_path)
print(f'Model saved: {final_model_path}')

# Simpan class names
class_names_path = os.path.join(OUTPUT_DIR, 'class_names.json')
with open(class_names_path, 'w') as f:
    json.dump(list(test_generator.class_indices.keys()), f, indent=2)
print(f'Class names saved: {class_names_path}')

# Simpan history
history_path = os.path.join(OUTPUT_DIR, 'history.json')
with open(history_path, 'w') as f:
    json.dump(full_history, f, indent=2)
print(f'History saved: {history_path}')

# Simpan class indices
class_indices_path = os.path.join(OUTPUT_DIR, 'class_indices.json')
with open(class_indices_path, 'w') as f:
    json.dump(test_generator.class_indices, f, indent=2)
print(f'Class indices saved: {class_indices_path}')

print('\n=== Semua file telah disimpan ===')
# Out:
# Model saved: /content/BUSI_Model/model.keras
# Class names saved: /content/BUSI_Model/class_names.json
# History saved: /content/BUSI_Model/history.json
# Class indices saved: /content/BUSI_Model/class_indices.json
#
# === Semua file telah disimpan ===

# %% [markdown]
# ## 17. Verifikasi Model

# %%
loaded_model = keras.models.load_model(final_model_path)
print('Model berhasil di-load kembali.')

test_generator.reset()
x_test_sample, y_test_sample = next(test_generator)
predictions = loaded_model.predict(x_test_sample)

class_names_list = list(test_generator.class_indices.keys())
for i in range(min(3, len(x_test_sample))):
    pred_class = class_names_list[np.argmax(predictions[i])]
    confidence = np.max(predictions[i]) * 100
    print(f'Sample {i+1}: Predicted={pred_class}, Confidence={confidence:.2f}%')
    for j, cls in enumerate(class_names_list):
        print(f'  {cls}: {predictions[i][j] * 100:.2f}%')
# Out:
# Model berhasil di-load kembali.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Sample 1: Predicted=benign, Confidence=53.50%
#   benign: 53.50%
#   malignant: 27.84%
#   normal: 18.66%
# Sample 2: Predicted=benign, Confidence=53.88%
#   benign: 53.88%
#   malignant: 27.83%
#   normal: 18.29%
# Sample 3: Predicted=benign, Confidence=53.27%
#   benign: 53.27%
#   malignant: 28.29%
#   normal: 18.44%

# %% [markdown]
# ## 18. Download Hasil ke Komputer Lokal

# %%
from google.colab import files

output_files = [
    'model.keras',
    'class_names.json',
    'class_indices.json',
    'history.json',
    'confusion_matrix.png',
    'training_history.png'
]

for f in output_files:
    path = os.path.join(OUTPUT_DIR, f)
    if os.path.exists(path):
        files.download(path)
        print(f'Downloaded: {f}')
    else:
        print(f'Not found: {f}')

print('\nSemua file selesai di-download.')
# Out:
# Downloaded: model.keras
# Downloaded: class_names.json
# Downloaded: class_indices.json
# Downloaded: history.json
# Downloaded: confusion_matrix.png
# Downloaded: training_history.png
#
# Semua file selesai di-download.

# %% [markdown]
# ---
# ## Selesai
#
# File yang dihasilkan:
# - **model.keras** - Model final
# - **class_names.json** - Daftar kelas
# - **class_indices.json** - Mapping index ke kelas
# - **history.json** - Riwayat training
# - **confusion_matrix.png** - Confusion matrix
# - **training_history.png** - Plot accuracy & loss
